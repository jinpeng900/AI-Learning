# %% [markdown]
# ## 监督学习算法

# %% [markdown]
# ### 线性回归(Linear Regression)
# 应用场景：房价预测、销售预测、股票价格预测
#
# 线性回归是一种基本的监督学习算法，用于预测连续数值。它假设输入特征与输出之间存在线性关系，模型形式如下：
#
# $$y = w_0 + w_1x_1 + w_2x_2 + ... + w_nx_n + b$$
# - y 是预测值(目标值)
# - x_i 是输入特征
# - w_i 是权重参数
# - b 是偏置项
#
# 线性回归的目标是找到最佳的权重参数，使得预测值与实际值之间的误差最小化。常用的优化方法是最小二乘法。
