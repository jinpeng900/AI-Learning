# %% [markdown]
# # Pandas 数据排序与聚合
#
# 数据排序与聚合是数据分析中非常常见且重要的操作，特别是在大数据集中的数据分析时。
#
# 排序帮助我们按特定标准对数据进行排列，而聚合则让我们对数据进行汇总，计算出各种统计量。
#
# Pandas 提供了强大的排序和聚合功能，能够帮助分析人员高效地处理数据。
#
# | 操作 | 方法 | 说明 | 常用函数/方法 |
# |------|------|------|---------------|
# | 排序 | sort_values(by, ascending) | 根据某列的值进行排序，ascending 控制升降序 | df.sort_values(by='column') |
# | 排序 | sort_index(axis) | 根据行或列的索引进行排序 | df.sort_index(axis=0) |
# | 分组聚合 | groupby(by) | 按照某列进行分组后，应用聚合函数 | df.groupby('column') |
# | 聚合函数 | agg() | 聚合函数，如 sum()、mean()、count() 等 | df.groupby('column').agg({'value': 'sum'}) |
# | 多重聚合 | agg([func1, func2]) | 对同一列应用多个聚合函数 | df.groupby('column').agg({'value': ['mean', 'sum']}) |
# | 分组后排序 | apply(lambda x: x.sort_values(...)) | 在分组后进行排序 | df.groupby('column').apply(lambda x: x.sort_values(...)) |
# | 透视表 | pivot_table() | 创建透视表，根据行、列进行数据汇总 | |

# %%
import pandas as pd
# 排序实例 - sort_values()

# 示例数据
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40],
        'Salary': [50000, 60000, 70000, 80000]}

df = pd.DataFrame(data)

# 按年龄排序
df.sort_values(by='Age', inplace=True , ascending=False)
print(df)
# Out:
#       Name  Age  Salary
# 3    David   40   80000
# 2  Charlie   35   70000
# 1      Bob   30   60000
# 0    Alice   25   50000

# %%
# 排序实例 - sort_index()
df_sorted_index = df.sort_index()
print(df_sorted_index)
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# 3    David   40   80000

# %%
# 分组聚合实例 - groupby()
data = {'Department': ['HR', 'Finance', 'HR', 'IT', 'IT'],
        'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Salary': [50000, 60000, 55000, 70000, 75000]}

df = pd.DataFrame(data)

# 按照部门分组，并计算每个部门的平均薪资
grouped = df.groupby('Department')['Salary'].mean()
print(grouped)
# Out:
# Department
# Finance    60000.0
# HR         52500.0
# IT         72500.0
# Name: Salary, dtype: float64

# %%
# 多重聚合函数

# 按照部门分组，并计算每个部门的薪资的平均值和总和
grouped_multiple = df.groupby('Department').agg({'Salary': ['mean', 'sum']})
print(grouped_multiple)
# Out:
#              Salary
#                mean     sum
# Department
# Finance     60000.0   60000
# HR          52500.0  105000
# IT          72500.0  145000

# %%
# 分组后排序
# 按照部门分组后，按薪资降序排序
# df.groupby(by).apply(lambda x: x.sort_values(by='col'))

# 分组后排序
# 按照部门分组后，按薪资降序排序
grouped_sorted = df.groupby('Department').apply(lambda x: x.sort_values(by='Salary', ascending=False))
print(grouped_sorted)
# Out:
#              Department Employee  Salary
# Department
# Finance    1    Finance      Bob   60000
# HR         2         HR  Charlie   55000
#            0         HR    Alice   50000
# IT         4         IT      Eve   75000
#            3         IT    David   70000
# C:\Users\24应统赵金鹏\AppData\Local\Temp\ipykernel_24556\1047241774.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_sorted = df.groupby('Department').apply(lambda x: x.sort_values(by='Salary', ascending=False))

# %%
# 透视表
# 使用 pivot_table 计算每个部门的薪资平均值
pivot_table = df.pivot_table(values='Salary', index='Department', aggfunc='mean')
print(pivot_table)
# Out:
#              Salary
# Department
# Finance     60000.0
# HR          52500.0
# IT          72500.0
