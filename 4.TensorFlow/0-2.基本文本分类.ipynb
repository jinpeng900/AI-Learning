# %%
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import losses
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777824504.959652 1051635 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1777824505.322007 1051635 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777824507.121802 1051635 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# url = "https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz"

# dataset = tf.keras.utils.get_file("aclImdb_v1", url,
#                                     untar=True, cache_dir='.',
#                                     cache_subdir='')

dataset_dir = os.path.join('aclImdb')

# %%
os.listdir(dataset_dir)     # ['train', 'test', 'imdb.vocab', 'README']
# Out:
# ['test', 'README', 'train', 'imdbEr.txt', 'imdb.vocab']

# %%
train_dir = os.path.join(dataset_dir, 'train')
os.listdir(train_dir)     # ['neg', 'pos', 'unsupBow.feat', 'unsupBow.txt', 'unsup_labelledBow.feat', 'unsup_labelledBow.txt']
# Out:
# ['urls_pos.txt',
#  'urls_unsup.txt',
#  'unsupBow.feat',
#  'neg',
#  'pos',
#  'urls_neg.txt',
#  'labeledBow.feat']

# %%
sample_file = os.path.join(train_dir, 'pos/1181_9.txt')
with open(sample_file) as f:
    print(f.read())
# Out:
# Rachel Griffiths writes and directs this award winning short film. A heartwarming story about coping with grief and cherishing the memory of those we've loved and lost. Although, only 15 minutes long, Griffiths manages to capture so much emotion and truth onto film in the short space of time. Bud Tingwell gives a touching performance as Will, a widower struggling to cope with his wife's death. Will is confronted by the harsh reality of loneliness and helplessness as he proceeds to take care of Ruth's pet cow, Tulip. The film displays the grief and responsibility one feels for those they have loved and lost. Good cinematography, great direction, and superbly acted. It will bring tears to all those who have lost a loved one, and survived.

# %%
remove_dir = os.path.join(train_dir, 'unsup')
shutil.rmtree(remove_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 remove_dir = os.path.join(train_dir, 'unsup')
# ----> 2 shutil.rmtree(remove_dir)
#
# File /usr/lib/python3.12/shutil.py:775, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     773     orig_st = os.lstat(path, dir_fd=dir_fd)
#     774 except Exception as err:
# --> 775     onexc(os.lstat, path, err)
#     776     return
#     777 try:
#
# File /usr/lib/python3.12/shutil.py:773, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     770 # Note: To guard against symlink races, we use the standard
#     771 # lstat()/open()/fstat() trick.
#     772 try:
# --> 773     orig_st = os.lstat(path, dir_fd=dir_fd)
#     774 except Exception as err:
#     775     onexc(os.lstat, path, err)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'aclImdb/train/unsup'

# %%
batch_size = 32                     # batch_size 用来控制每次训练的样本数量
seed = 42                           # 随机种子，保证每次运行结果一样

raw_train_ds = tf.keras.preprocessing.text_dataset_from_directory(
    'aclImdb/train',
    batch_size=batch_size,
    validation_split=0.2,
    subset='training',
    seed=seed)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# E0000 00:00:1777563889.523190   26428 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
for text_ba
